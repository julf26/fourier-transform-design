# %% [markdown]
# **NAMA : ZULFIKRI**
#
# **NRP : 07311940000051**
#
# **EAS DPS "Final Project Merancang Filter"**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
 
df = pd.read_excel('/content/drive/MyDrive/DPS/SuddecCardiacDeathv3.xlsx')
df = df.drop(df.index[0])
df
# Out:
#      sample interval      ECG 1     ECG 2
# 1                  0     -0.281     0.247
# 2                  1  -0.254098     0.242
# 3                  2  -0.215221     0.231
# 4                  3  -0.184098      0.23
# 5                  4  -0.154894     0.224
# ...              ...        ...       ...
# 2496            2495     -0.148     -0.02
# 2497            2496  -0.125106     0.007
# 2498            2497 -0.0919017      0.02
# 2499            2498 -0.0587785    -0.019
# 2500            2499 -0.0239017    -0.115
#
# [2500 rows x 3 columns]

# %%
list(df.columns)
# Out:
# ['sample interval', '    ECG 1', '    ECG 2']

# %%
import matplotlib.pyplot as plt
import numpy as np

sample = df['sample interval'].values * 0.004
ecg1 = df['    ECG 1'].values
ecg2 = df['    ECG 2'].values


plt.figure(figsize=(15,5))
plt.plot(sample, ecg1, label='ECG 1')
plt.plot(sample, ecg2, label='ECG 2')
plt.title('Suddec Cardiac Death')
plt.xlabel('Waktu (s)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.ylabel('Amplitudo (mV)')
plt.grid()
plt.legend()

#mpld3.display()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import numpy as np
ec1 = ecg1.reshape(1,-1)
ec2 = ecg2.reshape(1,-1)
N = len(ecg1)
n = np.arange(0,N).reshape(1,-1)
k = np.arange(0,N).reshape(-1,1)
f= np.count_nonzero(n+1)/(0.004*len(sample))

"""
#ECG 1
for k in range(n):
  for i in range(n):
      real[k] = real[k] + ecg1[i]*np.cos(2*np.pi*k*n/N)
      imj[k] = imj[k] - ecg1[i]*np.sin(2*np.pi*k*n/N)
    
for k in range(n):
  mag[k] = np.sqrt((real[k])**2 + (imj[k])**2)
"""
#DFT
scalar = -2j * np.pi / N
matrix =  k * n
mat = scalar * matrix
e = np.exp(mat)

#ECG 1
xk1 = np.sum(ec1 * e, axis=1)
xk_amplitude1 = np.absolute(xk1)

#ECG 2
xk2 = np.sum(ec2 * e, axis=1)
xk_amplitude2 = np.absolute(xk2)

k = k.reshape(-1)

fig, ax = plt.subplots(2, figsize=(20,10))
ax[0].bar(k*f/N, xk_amplitude1)
ax[0].set_title('DFT ECG 1')
ax[0].set_xlim(0,f/2)
ax[0].set_xticks(np.arange(0, f/2, 5))
ax[0].set_xlabel('Frekuensi (Hz)')
ax[0].set_ylabel('Magnitude')
ax[0].grid()
ax[1].bar(k*f/N, xk_amplitude2, color='#ff8c00')
ax[1].set_title('DFT ECG 2')
ax[1].set_xlim(0,f/2)
ax[1].set_xticks(np.arange(0, f/2, 5))
ax[1].set_xlabel('Frekuensi (Hz)')
ax[1].set_ylabel('Magnitude')
ax[1].grid()

#mpld3.display()
plt.show()

# %%
m = int(input('Orde(m): ')) #jumlah orde
jumlh = len(df.index)
data1 = df['    ECG 1']
data2 = df['    ECG 2']
ndata = df['sample interval'].values

matrix_a = np.ones([m+1, m+1])
matrix_a[0,0] = 0
matrix_b1 = np.zeros(m+1, float)
matrix_b2 = np.zeros(m+1, float)
matrix_b1[0] = np.array(df['    ECG 1'].sum())
matrix_b2[0] = np.array(df['    ECG 2'].sum())
arr_a = ndata.reshape(-1,1,1)


amatrix = matrix_a*arr_a
bmatrix1 = matrix_b1
bmatrix2 = matrix_b2
#amp = df['data']
wkt = df['sample interval']


for i in range(m+1):
  for j in range(m+1):
    amatrix[:,i,j] = np.power(amatrix[:,i,j],i+j)
    #bmatrix[:,i,j] = np.power(bmatrix[:,i,j],i+j)*df['data'].sum()

for i in range(m+1):
  for k in range(jumlh):
    try:
      bmatrix1[0] = df['    ECG 1'].sum()
      bmatrix1[i] += data1[k]*(wkt[k]**i)
      bmatrix2[0] = df['    ECG 2'].sum()
      bmatrix2[i] += data2[k]*(wkt[k]**i)
    except KeyError:
      continue 

datasum_a = np.sum(amatrix, axis=0)

n=len(bmatrix1)
for i in range(0,n-1):
  for j in range(i+1,n): 
    if datasum_a[i,i]==0:
      break
    terms = datasum_a[j,i]/datasum_a[i,i]
    datasum_a[j,:] -= terms*datasum_a[i,:]
    bmatrix1[j] -= terms*bmatrix1[i]
    bmatrix2[j] -= terms*bmatrix2[i]

x1 = np.zeros(n, float)
x2 = np.zeros(n, float)
x1[n-1] = bmatrix1[n-1]/datasum_a[n-1, n-1]
x2[n-1] = bmatrix2[n-1]/datasum_a[n-1, n-1]
for i in range(n-2, -1, -1):
  terms1 = 0
  terms2 = 0 
  for j in range(i+1, n):
    terms1 += datasum_a[i, j] * x1[j]
    terms2 += datasum_a[i, j] * x2[j]
  x1[i] = (bmatrix1[i] - terms1)/datasum_a[i, i]
  x2[i] = (bmatrix2[i] - terms2)/datasum_a[i, i]

y1 = np.zeros(len(df.index))
y2 = np.zeros(len(df.index))

for k in range(m+1):
    for i in range(len(df.index)):
      try:
        y1[i] += x1[k]*(wkt[i]**k)
        y2[i] += x2[k]*(wkt[i]**k)
      except KeyError:
        continue

fig, ax = plt.subplots(2, figsize=(20,10))
ax[0].plot(sample, data1, label = 'Data Awal')
ax[0].plot(sample, data1-y1, label = 'Hasil Akhir')
ax[0].set_title('Hasil Regresi ECG 1')
ax[0].set_xlabel('Time (s)')
ax[0].set_ylabel('Amplitudo(mV)')
ax[0].set_xticks(np.arange(0, 11, 1))
ax[0].set_xlim(0,10)
ax[0].legend()
ax[0].grid()
ax[1].plot(sample, data2, label = 'Data Awal')
ax[1].plot(sample, data2-y2, label = 'Hasil Akhir')
ax[1].set_title('Hasil Regresi ECG 2')
ax[1].set_xlabel('Time (s)')
ax[1].set_ylabel('Amplitudo(mV)')
ax[1].set_xticks(np.arange(0, 11, 1))
ax[1].set_xlim(0,10)
ax[1].legend()
ax[1].grid()
plt.show()
# Out:
# Orde(m): 30

# %%
#DFT Hasil curve fitting
k = np.arange(0,N).reshape(-1,1)
n = np.arange(0,N).reshape(1,-1)
scalar = -2j * np.pi / N
matrix =  k * n
mat = scalar * matrix
e = np.exp(mat)

r1 = np.stack(data1-y1).astype(None)
r2 = np.stack(data2-y2).astype(None)
r1a = r1.reshape(1,-1)
r2a = r2.reshape(1,-1)
#ECG 1
yd1 = np.sum(r1a * e, axis=1)
yd_amplitude1 = np.absolute(yd1)

#ECG 2
yd2 = np.sum(r2a * e, axis=1)
yd_amplitude2 = np.absolute(yd2)

k = k.reshape(-1)

fig, ax = plt.subplots(2, figsize=(20,10))
ax[0].bar(k*f/N, yd_amplitude1)
ax[0].set_title('DFT Hasil Regresi ECG 1')
ax[0].set_xlim(0,f/2)
ax[0].set_xticks(np.arange(0, f/2, 5))
ax[0].set_xlabel('Frekuensi (Hz)')
ax[0].set_ylabel('Magnitude')
ax[0].grid()
ax[1].bar(k*f/N, yd_amplitude2, color='#ff8c00')
ax[1].set_title('DFT Hasil Regresi ECG 2')
ax[1].set_xlim(0,f/2)
ax[1].set_xticks(np.arange(0, f/2, 5))
ax[1].set_xlabel('Frekuensi (Hz)')
ax[1].set_ylabel('Magnitude')
ax[1].grid()
plt.show()

# %%
import matplotlib.gridspec as gridspec

# Berdasarkan rumus Ohm=2pif/fs, karena fs=250 dan -pi<Ohm<pi, maka -250<f<251
fArr = np.arange(-f, f+1)
    # X axis (dalam Ohm)
X = fArr*np.pi/f
    # Y axis
temp = np.abs(fArr)
Y = np.where(np.logical_and(temp >= 0, temp <= np.pi), 1, 0)
Y2 = np.where(np.logical_and(temp >= 0, temp <= np.pi), 0, 1)

fc = float(input('Frekuensi Cut-off: '))
orde = int(input('Order filter: '))
f = 1/0.004

ohm = 2*np.pi*fc/f
M = int((orde-1)/2)
i = np.arange(-M, M+1)

#Persamaan Filter
hi=np.where(i!=0,np.sin(ohm*i)/(np.pi*i),ohm/np.pi) #lowpass
hii=np.where(i!=0,-np.sin(ohm*i)/(np.pi*i),(np.pi-ohm)/np.pi) #highpass

z = np.reshape(np.arange(0, (2 * M + 1)), (-1, 1))
i_j_ohm = -1j*z*X

#e^ Matriks i_j_ohm
e_j_i_ohm = np.exp(i_j_ohm, dtype='complex64')
    
# Perkalian matriks persamaan filter dengan e^jiOhm
Response1 = np.matmul(hi, e_j_i_ohm)
Response2 = np.matmul(hii, e_j_i_ohm)
Y2_1 = np.absolute(Response1)
Y2_2 = np.absolute(Response2)

X1 = np.arange(-M, M + 1)

#Filter Forward
x1 = data1-y1
x2 = data2

yi1 = np.zeros(len(df.index))
yi2 = np.zeros(len(df.index))
#persamaan filter(Forward)
for k in range(0, 2*M+1):
    for n in range(len(df.index)):
      try:
        yi1[n] += hi[k-M]*x1[n-k]
        yi2[n] += hii[k-M]*x2[n-k]
      except KeyError:
        continue

#filter backward

yii1 = np.zeros(len(df.index))
yii2 = np.zeros(len(df.index))

#persamaan filter
for k in range(2*M+1): 
    for n in range(len(df.index)):
      try:
        yii1[n] += hi[k-M]*yi1[n+k]
        yii2[n] += hii[k-M]*yi2[n+k]
      except KeyError:
        continue
      except IndexError:
        continue
    
fig = plt.figure(figsize=(20,12))
gs = gridspec.GridSpec(4, 4, wspace=0.5, hspace=0.5)

ax1 = plt.subplot(gs[0, :-2])
plt.plot(X, Y, label='Ideal Response')
plt.plot(X, Y2_1, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Lowpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax2 = plt.subplot(gs[0, 2:])
plt.stem(X1, hi, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax3 = plt.subplot(gs[1, :-2])
plt.plot(X, Y2, label='Ideal Response')
plt.plot(X, Y2_2, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Highpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax4 = plt.subplot(gs[1, 2:])
plt.stem(X1, hii, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax5 = plt.subplot(gs[2, :])
plt.plot(sample, x1, label = 'Data Awal')
plt.plot(sample, yi1, label = 'Hasil Forward Filter')
plt.plot(sample, yii1, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 1')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

ax6 = plt.subplot(gs[3, :])
plt.plot(sample, x2, label = 'Data Awal')
plt.plot(sample, yi2, label = 'Hasil Forward Filter')
plt.plot(sample, yii2, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 2')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

plt.show()
# Out:
# Frekuensi Cut-off: 20
# Order filter: 5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide

# %%
import matplotlib.gridspec as gridspec

# Berdasarkan rumus Ohm=2pif/fs, karena fs=250 dan -pi<Ohm<pi, maka -250<f<251
fArr = np.arange(-f, f+1)
    # X axis (dalam Ohm)
X = fArr*np.pi/f
    # Y axis
temp = np.abs(fArr)
Y = np.where(np.logical_and(temp >= 0, temp <= np.pi), 1, 0)
Y2 = np.where(np.logical_and(temp >= 0, temp <= np.pi), 0, 1)

fc = float(input('Frekuensi Cut-off: '))
orde = int(input('Order filter: '))
f = 1/0.004

ohm = 2*np.pi*fc/f
M = int((orde-1)/2)
i = np.arange(-M, M+1)

#Persamaan Filter
hi=np.where(i!=0,np.sin(ohm*i)/(np.pi*i),ohm/np.pi) #lowpass
hii=np.where(i!=0,-np.sin(ohm*i)/(np.pi*i),(np.pi-ohm)/np.pi) #highpass

z = np.reshape(np.arange(0, (2 * M + 1)), (-1, 1))
i_j_ohm = -1j*z*X

#e^ Matriks i_j_ohm
e_j_i_ohm = np.exp(i_j_ohm, dtype='complex64')
    
# Perkalian matriks persamaan filter dengan e^jiOhm
Response1 = np.matmul(hi, e_j_i_ohm)
Response2 = np.matmul(hii, e_j_i_ohm)
Y2_1 = np.absolute(Response1)
Y2_2 = np.absolute(Response2)

X1 = np.arange(-M, M + 1)

#Filter Forward
x1 = data1-y1
x2 = data2

yi1 = np.zeros(len(df.index))
yi2 = np.zeros(len(df.index))
#persamaan filter(Forward)
for k in range(0, 2*M+1):
    for n in range(len(df.index)):
      try:
        yi1[n] += hi[k-M]*x1[n-k]
        yi2[n] += hii[k-M]*x2[n-k]
      except KeyError:
        continue

#filter backward

yii1 = np.zeros(len(df.index))
yii2 = np.zeros(len(df.index))

#persamaan filter
for k in range(2*M+1): 
    for n in range(len(df.index)):
      try:
        yii1[n] += hi[k-M]*yi1[n+k]
        yii2[n] += hii[k-M]*yi2[n+k]
      except KeyError:
        continue
      except IndexError:
        continue
    
fig = plt.figure(figsize=(20,12))
gs = gridspec.GridSpec(4, 4, wspace=0.5, hspace=0.5)

ax1 = plt.subplot(gs[0, :-2])
plt.plot(X, Y, label='Ideal Response')
plt.plot(X, Y2_1, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Lowpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax2 = plt.subplot(gs[0, 2:])
plt.stem(X1, hi, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax3 = plt.subplot(gs[1, :-2])
plt.plot(X, Y2, label='Ideal Response')
plt.plot(X, Y2_2, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Highpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax4 = plt.subplot(gs[1, 2:])
plt.stem(X1, hii, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax5 = plt.subplot(gs[2, :])
plt.plot(sample, x1, label = 'Data Awal')
plt.plot(sample, yi1, label = 'Hasil Forward Filter')
plt.plot(sample, yii1, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 1')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

ax6 = plt.subplot(gs[3, :])
plt.plot(sample, x2, label = 'Data Awal')
plt.plot(sample, yi2, label = 'Hasil Forward Filter')
plt.plot(sample, yii2, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 2')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

plt.show()
# Out:
# Frekuensi Cut-off: 20
# Order filter: 15
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide

# %%
import matplotlib.gridspec as gridspec

# Berdasarkan rumus Ohm=2pif/fs, karena fs=250 dan -pi<Ohm<pi, maka -250<f<251
fArr = np.arange(-f, f+1)
    # X axis (dalam Ohm)
X = fArr*np.pi/f
    # Y axis
temp = np.abs(fArr)
Y = np.where(np.logical_and(temp >= 0, temp <= np.pi), 1, 0)
Y2 = np.where(np.logical_and(temp >= 0, temp <= np.pi), 0, 1)

fc = float(input('Frekuensi Cut-off: '))
orde = int(input('Order filter: '))
f = 1/0.004

ohm = 2*np.pi*fc/f
M = int((orde-1)/2)
i = np.arange(-M, M+1)

#Persamaan Filter
hi=np.where(i!=0,np.sin(ohm*i)/(np.pi*i),ohm/np.pi) #lowpass
hii=np.where(i!=0,-np.sin(ohm*i)/(np.pi*i),(np.pi-ohm)/np.pi) #highpass

z = np.reshape(np.arange(0, (2 * M + 1)), (-1, 1))
i_j_ohm = -1j*z*X

#e^ Matriks i_j_ohm
e_j_i_ohm = np.exp(i_j_ohm, dtype='complex64')
    
# Perkalian matriks persamaan filter dengan e^jiOhm
Response1 = np.matmul(hi, e_j_i_ohm)
Response2 = np.matmul(hii, e_j_i_ohm)
Y2_1 = np.absolute(Response1)
Y2_2 = np.absolute(Response2)

X1 = np.arange(-M, M + 1)

#Filter Forward
x1 = data1-y1
x2 = data2

yi1 = np.zeros(len(df.index))
yi2 = np.zeros(len(df.index))
#persamaan filter(Forward)
for k in range(0, 2*M+1):
    for n in range(len(df.index)):
      try:
        yi1[n] += hi[k-M]*x1[n-k]
        yi2[n] += hii[k-M]*x2[n-k]
      except KeyError:
        continue

#filter backward

yii1 = np.zeros(len(df.index))
yii2 = np.zeros(len(df.index))

#persamaan filter
for k in range(2*M+1): 
    for n in range(len(df.index)):
      try:
        yii1[n] += hi[k-M]*yi1[n+k]
        yii2[n] += hii[k-M]*yi2[n+k]
      except KeyError:
        continue
      except IndexError:
        continue
    
fig = plt.figure(figsize=(20,12))
gs = gridspec.GridSpec(4, 4, wspace=0.5, hspace=0.5)

ax1 = plt.subplot(gs[0, :-2])
plt.plot(X, Y, label='Ideal Response')
plt.plot(X, Y2_1, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Lowpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax2 = plt.subplot(gs[0, 2:])
plt.stem(X1, hi, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax3 = plt.subplot(gs[1, :-2])
plt.plot(X, Y2, label='Ideal Response')
plt.plot(X, Y2_2, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Highpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax4 = plt.subplot(gs[1, 2:])
plt.stem(X1, hii, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax5 = plt.subplot(gs[2, :])
plt.plot(sample, x1, label = 'Data Awal')
plt.plot(sample, yi1, label = 'Hasil Forward Filter')
plt.plot(sample, yii1, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 1')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

ax6 = plt.subplot(gs[3, :])
plt.plot(sample, x2, label = 'Data Awal')
plt.plot(sample, yi2, label = 'Hasil Forward Filter')
plt.plot(sample, yii2, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 2')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

plt.show()
# Out:
# Frekuensi Cut-off: 20
# Order filter: 20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide

# %%
import matplotlib.gridspec as gridspec

# Berdasarkan rumus Ohm=2pif/fs, karena fs=250 dan -pi<Ohm<pi, maka -250<f<251
fArr = np.arange(-f, f+1)
    # X axis (dalam Ohm)
X = fArr*np.pi/f
    # Y axis
temp = np.abs(fArr)
Y = np.where(np.logical_and(temp >= 0, temp <= np.pi), 1, 0)
Y2 = np.where(np.logical_and(temp >= 0, temp <= np.pi), 0, 1)

fc = float(input('Frekuensi Cut-off: '))
orde = int(input('Order filter: '))
f = 1/0.004

ohm = 2*np.pi*fc/f
M = int((orde-1)/2)
i = np.arange(-M, M+1)

#Persamaan Filter
hi=np.where(i!=0,np.sin(ohm*i)/(np.pi*i),ohm/np.pi) #lowpass
hii=np.where(i!=0,-np.sin(ohm*i)/(np.pi*i),(np.pi-ohm)/np.pi) #highpass

z = np.reshape(np.arange(0, (2 * M + 1)), (-1, 1))
i_j_ohm = -1j*z*X

#e^ Matriks i_j_ohm
e_j_i_ohm = np.exp(i_j_ohm, dtype='complex64')
    
# Perkalian matriks persamaan filter dengan e^jiOhm
Response1 = np.matmul(hi, e_j_i_ohm)
Response2 = np.matmul(hii, e_j_i_ohm)
Y2_1 = np.absolute(Response1)
Y2_2 = np.absolute(Response2)

X1 = np.arange(-M, M + 1)

#Filter Forward
x1 = data1-y1
x2 = data2

yi1 = np.zeros(len(df.index))
yi2 = np.zeros(len(df.index))
#persamaan filter(Forward)
for k in range(0, 2*M+1):
    for n in range(len(df.index)):
      try:
        yi1[n] += hi[k-M]*x1[n-k]
        yi2[n] += hii[k-M]*x2[n-k]
      except KeyError:
        continue

#filter backward

yii1 = np.zeros(len(df.index))
yii2 = np.zeros(len(df.index))

#persamaan filter
for k in range(2*M+1): 
    for n in range(len(df.index)):
      try:
        yii1[n] += hi[k-M]*yi1[n+k]
        yii2[n] += hii[k-M]*yi2[n+k]
      except KeyError:
        continue
      except IndexError:
        continue
    
fig = plt.figure(figsize=(20,12))
gs = gridspec.GridSpec(4, 4, wspace=0.5, hspace=0.5)

ax1 = plt.subplot(gs[0, :-2])
plt.plot(X, Y, label='Ideal Response')
plt.plot(X, Y2_1, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Lowpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax2 = plt.subplot(gs[0, 2:])
plt.stem(X1, hi, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax3 = plt.subplot(gs[1, :-2])
plt.plot(X, Y2, label='Ideal Response')
plt.plot(X, Y2_2, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Highpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax4 = plt.subplot(gs[1, 2:])
plt.stem(X1, hii, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax5 = plt.subplot(gs[2, :])
plt.plot(sample, x1, label = 'Data Awal')
plt.plot(sample, yi1, label = 'Hasil Forward Filter')
plt.plot(sample, yii1, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 1')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

ax6 = plt.subplot(gs[3, :])
plt.plot(sample, x2, label = 'Data Awal')
plt.plot(sample, yi2, label = 'Hasil Forward Filter')
plt.plot(sample, yii2, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 2')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

plt.show()
# Out:
# Frekuensi Cut-off: 5
# Order filter: 15
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide

# %%
import matplotlib.gridspec as gridspec

# Berdasarkan rumus Ohm=2pif/fs, karena fs=250 dan -pi<Ohm<pi, maka -250<f<251
fArr = np.arange(-f, f+1)
    # X axis (dalam Ohm)
X = fArr*np.pi/f
    # Y axis
temp = np.abs(fArr)
Y = np.where(np.logical_and(temp >= 0, temp <= np.pi), 1, 0)
Y2 = np.where(np.logical_and(temp >= 0, temp <= np.pi), 0, 1)

fc = float(input('Frekuensi Cut-off: '))
orde = int(input('Order filter: '))
f = 1/0.004

ohm = 2*np.pi*fc/f
M = int((orde-1)/2)
i = np.arange(-M, M+1)

#Persamaan Filter
hi=np.where(i!=0,np.sin(ohm*i)/(np.pi*i),ohm/np.pi) #lowpass
hii=np.where(i!=0,-np.sin(ohm*i)/(np.pi*i),(np.pi-ohm)/np.pi) #highpass

z = np.reshape(np.arange(0, (2 * M + 1)), (-1, 1))
i_j_ohm = -1j*z*X

#e^ Matriks i_j_ohm
e_j_i_ohm = np.exp(i_j_ohm, dtype='complex64')
    
# Perkalian matriks persamaan filter dengan e^jiOhm
Response1 = np.matmul(hi, e_j_i_ohm)
Response2 = np.matmul(hii, e_j_i_ohm)
Y2_1 = np.absolute(Response1)
Y2_2 = np.absolute(Response2)

X1 = np.arange(-M, M + 1)

#Filter Forward
x1 = data1-y1
x2 = data2

yi1 = np.zeros(len(df.index))
yi2 = np.zeros(len(df.index))
#persamaan filter(Forward)
for k in range(0, 2*M+1):
    for n in range(len(df.index)):
      try:
        yi1[n] += hi[k-M]*x1[n-k]
        yi2[n] += hii[k-M]*x2[n-k]
      except KeyError:
        continue

#filter backward

yii1 = np.zeros(len(df.index))
yii2 = np.zeros(len(df.index))

#persamaan filter
for k in range(2*M+1): 
    for n in range(len(df.index)):
      try:
        yii1[n] += hi[k-M]*yi1[n+k]
        yii2[n] += hii[k-M]*yi2[n+k]
      except KeyError:
        continue
      except IndexError:
        continue
    
fig = plt.figure(figsize=(20,12))
gs = gridspec.GridSpec(4, 4, wspace=0.5, hspace=0.5)

ax1 = plt.subplot(gs[0, :-2])
plt.plot(X, Y, label='Ideal Response')
plt.plot(X, Y2_1, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Lowpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax2 = plt.subplot(gs[0, 2:])
plt.stem(X1, hi, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax3 = plt.subplot(gs[1, :-2])
plt.plot(X, Y2, label='Ideal Response')
plt.plot(X, Y2_2, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Highpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax4 = plt.subplot(gs[1, 2:])
plt.stem(X1, hii, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax5 = plt.subplot(gs[2, :])
plt.plot(sample, x1, label = 'Data Awal')
plt.plot(sample, yi1, label = 'Hasil Forward Filter')
plt.plot(sample, yii1, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 1')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

ax6 = plt.subplot(gs[3, :])
plt.plot(sample, x2, label = 'Data Awal')
plt.plot(sample, yi2, label = 'Hasil Forward Filter')
plt.plot(sample, yii2, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 2')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

plt.show()
# Out:
# Frekuensi Cut-off: 10
# Order filter: 15
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide

# %%
import matplotlib.gridspec as gridspec

# Berdasarkan rumus Ohm=2pif/fs, karena fs=250 dan -pi<Ohm<pi, maka -250<f<251
fArr = np.arange(-f, f+1)
    # X axis (dalam Ohm)
X = fArr*np.pi/f
    # Y axis
temp = np.abs(fArr)
Y = np.where(np.logical_and(temp >= 0, temp <= np.pi), 1, 0)
Y2 = np.where(np.logical_and(temp >= 0, temp <= np.pi), 0, 1)

fc = float(input('Frekuensi Cut-off: '))
orde = int(input('Order filter: '))
f = 1/0.004

ohm = 2*np.pi*fc/f
M = int((orde-1)/2)
i = np.arange(-M, M+1)

#Persamaan Filter
hi=np.where(i!=0,np.sin(ohm*i)/(np.pi*i),ohm/np.pi) #lowpass
hii=np.where(i!=0,-np.sin(ohm*i)/(np.pi*i),(np.pi-ohm)/np.pi) #highpass

z = np.reshape(np.arange(0, (2 * M + 1)), (-1, 1))
i_j_ohm = -1j*z*X

#e^ Matriks i_j_ohm
e_j_i_ohm = np.exp(i_j_ohm, dtype='complex64')
    
# Perkalian matriks persamaan filter dengan e^jiOhm
Response1 = np.matmul(hi, e_j_i_ohm)
Response2 = np.matmul(hii, e_j_i_ohm)
Y2_1 = np.absolute(Response1)
Y2_2 = np.absolute(Response2)

X1 = np.arange(-M, M + 1)

#Filter Forward
x1 = data1-y1
x2 = data2

yi1 = np.zeros(len(df.index))
yi2 = np.zeros(len(df.index))
#persamaan filter(Forward)
for k in range(0, 2*M+1):
    for n in range(len(df.index)):
      try:
        yi1[n] += hi[k-M]*x1[n-k]
        yi2[n] += hii[k-M]*x2[n-k]
      except KeyError:
        continue

#filter backward

yii1 = np.zeros(len(df.index))
yii2 = np.zeros(len(df.index))

#persamaan filter
for k in range(2*M+1): 
    for n in range(len(df.index)):
      try:
        yii1[n] += hi[k-M]*yi1[n+k]
        yii2[n] += hii[k-M]*yi2[n+k]
      except KeyError:
        continue
      except IndexError:
        continue
    
fig = plt.figure(figsize=(20,12))
gs = gridspec.GridSpec(4, 4, wspace=0.5, hspace=0.5)

ax1 = plt.subplot(gs[0, :-2])
plt.plot(X, Y, label='Ideal Response')
plt.plot(X, Y2_1, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Lowpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax2 = plt.subplot(gs[0, 2:])
plt.stem(X1, hi, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax3 = plt.subplot(gs[1, :-2])
plt.plot(X, Y2, label='Ideal Response')
plt.plot(X, Y2_2, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Highpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax4 = plt.subplot(gs[1, 2:])
plt.stem(X1, hii, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax5 = plt.subplot(gs[2, :])
plt.plot(sample, x1, label = 'Data Awal')
plt.plot(sample, yi1, label = 'Hasil Forward Filter')
plt.plot(sample, yii1, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 1')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

ax6 = plt.subplot(gs[3, :])
plt.plot(sample, x2, label = 'Data Awal')
plt.plot(sample, yi2, label = 'Hasil Forward Filter')
plt.plot(sample, yii2, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 2')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

plt.show()
# Out:
# Frekuensi Cut-off: 15
# Order filter: 15
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide

# %%
import matplotlib.gridspec as gridspec

# Berdasarkan rumus Ohm=2pif/fs, karena fs=250 dan -pi<Ohm<pi, maka -250<f<251
fArr = np.arange(-f, f+1)
    # X axis (dalam Ohm)
X = fArr*np.pi/f
    # Y axis
temp = np.abs(fArr)
Y = np.where(np.logical_and(temp >= 0, temp <= np.pi), 1, 0)
Y2 = np.where(np.logical_and(temp >= 0, temp <= np.pi), 0, 1)

fc = float(input('Frekuensi Cut-off: '))
orde = int(input('Order filter: '))
f = 1/0.004

ohm = 2*np.pi*fc/f
M = int((orde-1)/2)
i = np.arange(-M, M+1)

#Persamaan Filter
hi=np.where(i!=0,np.sin(ohm*i)/(np.pi*i),ohm/np.pi) #lowpass
hii=np.where(i!=0,-np.sin(ohm*i)/(np.pi*i),(np.pi-ohm)/np.pi) #highpass

z = np.reshape(np.arange(0, (2 * M + 1)), (-1, 1))
i_j_ohm = -1j*z*X

#e^ Matriks i_j_ohm
e_j_i_ohm = np.exp(i_j_ohm, dtype='complex64')
    
# Perkalian matriks persamaan filter dengan e^jiOhm
Response1 = np.matmul(hi, e_j_i_ohm)
Response2 = np.matmul(hii, e_j_i_ohm)
Y2_1 = np.absolute(Response1)
Y2_2 = np.absolute(Response2)

X1 = np.arange(-M, M + 1)

#Filter Forward
x1 = data1-y1
x2 = data2

yi1 = np.zeros(len(df.index))
yi2 = np.zeros(len(df.index))
#persamaan filter(Forward)
for k in range(0, 2*M+1):
    for n in range(len(df.index)):
      try:
        yi1[n] += hi[k-M]*x1[n-k]
        yi2[n] += hii[k-M]*x2[n-k]
      except KeyError:
        continue

#filter backward

yii1 = np.zeros(len(df.index))
yii2 = np.zeros(len(df.index))

#persamaan filter
for k in range(2*M+1): 
    for n in range(len(df.index)):
      try:
        yii1[n] += hi[k-M]*yi1[n+k]
        yii2[n] += hii[k-M]*yi2[n+k]
      except KeyError:
        continue
      except IndexError:
        continue
    
fig = plt.figure(figsize=(20,12))
gs = gridspec.GridSpec(4, 4, wspace=0.5, hspace=0.5)

ax1 = plt.subplot(gs[0, :-2])
plt.plot(X, Y, label='Ideal Response')
plt.plot(X, Y2_1, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Lowpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax2 = plt.subplot(gs[0, 2:])
plt.stem(X1, hi, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax3 = plt.subplot(gs[1, :-2])
plt.plot(X, Y2, label='Ideal Response')
plt.plot(X, Y2_2, '--', label='Frequency Response')
plt.xlabel('Ohm')
plt.ylabel('Amplitude')
plt.title('Response Filter Highpass')
plt.xticks(np.arange(-M, M+1, 1))
plt.xlim(-np.pi-0.5, np.pi+0.5)
plt.legend()
plt.grid()

ax4 = plt.subplot(gs[1, 2:])
plt.stem(X1, hii, use_line_collection=True)
plt.xlabel('i')
plt.ylabel('h(i)')
plt.title('Impulse Response')
plt.grid()

ax5 = plt.subplot(gs[2, :])
plt.plot(sample, x1, label = 'Data Awal')
plt.plot(sample, yi1, label = 'Hasil Forward Filter')
plt.plot(sample, yii1, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 1')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

ax6 = plt.subplot(gs[3, :])
plt.plot(sample, x2, label = 'Data Awal')
plt.plot(sample, yi2, label = 'Hasil Forward Filter')
plt.plot(sample, yii2, label = 'Hasil Backward Filter')
plt.title('Hasil Filter FTD ECG 2')
plt.xlabel('Time (s)')
plt.ylabel('Amplitudo(mV)')
plt.xticks(np.arange(0, 11, 1))
plt.xlim(0,10)
plt.legend()
plt.grid()

plt.show()
# Out:
# Frekuensi Cut-off: 20
# Order filter: 50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in true_divide

# %%
#DFT Hasil Filter FTD
k = np.arange(0,N).reshape(-1,1)
n = np.arange(0,N).reshape(1,-1)
scalar = -2j * np.pi / N
matrix =  k * n
mat = scalar * matrix
e = np.exp(mat)

ri1 = np.stack(yi1).astype(None)
ri2 = np.stack(yi2).astype(None)
ri1a = ri1.reshape(1,-1)
ri2a = ri2.reshape(1,-1)
#ECG 1
ydi1 = np.sum(ri1a * e, axis=1)
yd_amplitudei1 = np.absolute(ydi1)

#ECG 2
ydi2 = np.sum(ri2a * e, axis=1)
yd_amplitudei2 = np.absolute(ydi2)


x = k*f/N

fig, ax = plt.subplots(2, figsize=(20,10))
ax[0].bar(x.flatten(), yd_amplitudei1)
ax[0].set_title('DFT Hasil Filter ECG 1')
ax[0].set_xlim(0,f/2)
ax[0].set_xticks(np.arange(0, f/2, 5))
ax[0].set_xlabel('Frekuensi (Hz)')
ax[0].set_ylabel('Magnitude')
ax[0].grid()
ax[1].bar(x.flatten(), yd_amplitudei2, color='#ff8c00')
ax[1].set_title('DFT Hasil Filter ECG 2')
ax[1].set_xlim(0,f/2)
ax[1].set_xticks(np.arange(0, f/2, 5))
ax[1].set_xlabel('Frekuensi (Hz)')
ax[1].set_ylabel('Magnitude')
ax[1].grid()
plt.show()

# %%
noise1 = x1 - yi1
noise2 = x2 - yi2

fig, ax = plt.subplots(2, figsize=(20,10))
ax[0].plot(wkt, noise1)
ax[0].set_title('Noise hasil filter ECG 1')
ax[0].set_xlabel('Time (s)')
ax[0].set_ylabel('Amplitudo(mV)')
ax[0].set_xticks(np.arange(0, len(df.index)+100, 100))
ax[0].grid()
ax[1].plot(wkt, noise2)
ax[1].set_title('Noise hasil filter ECG 2')
ax[1].set_xlabel('Time (s)')
ax[1].set_ylabel('Amplitudo(mV)')
ax[1].set_xticks(np.arange(0, len(df.index)+100, 100))
ax[1].grid()
plt.show()
